# %% [markdown]
# 실험 세팅
# - testset을 미리 떼 놓는다 (control 52 + ckd 52)
# - 각 seed 마다 CKD는 동일한데, Control은 바뀌면서 학습한다. (no cross-validation)

# %%
import random
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import torch
from torch import nn, optim
from torch.nn import functional as F

from sklearn.preprocessing import StandardScaler

from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, make_scorer, recall_score, precision_score, accuracy_score, roc_auc_score

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression 
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import cross_validate, StratifiedKFold

import xgboost as xgb

import os
import shap

import warnings
from sklearn.exceptions import ConvergenceWarning
import pickle
from joblib import dump, load

# ConvergenceWarning 경고를 무시
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %%
"""FUNCTIONS"""

# test에 나머지 control sample 추가해서 idx 만 반환
def divide_testset(unbalanced_data, ratio):
    # train에서 ckd, control index 확인
    total_idx = unbalanced_data.index
    ckd_idx = unbalanced_data[unbalanced_data['onset_tight'] == 1].index        # 실제 ckd
    control_idx = unbalanced_data[unbalanced_data['onset_tight'] == 0].index    # 실제 control
    # print(control_idx, ckd_idx)

    # ckd 갯수와 동일하게 control idx sampling
    rng = np.random.default_rng(seed=0) 
    sampled_ckd_idx = pd.Index(rng.choice(ckd_idx, size=int(len(ckd_idx)*ratio), replace=False))
    sampled_control_idx = pd.Index(rng.choice(control_idx, size=len(sampled_ckd_idx), replace=False)) # test_ckd 갯수와 동일하게 sampling
    
    test_idx = sampled_ckd_idx.append(sampled_control_idx)
    train_idx = total_idx.difference(test_idx)

    # return 실제 ckd, 실제 ckd 갯수와 동일한 갯수의 subject, control_idx - ckd_idx
    return unbalanced_data.loc[train_idx], unbalanced_data.loc[test_idx]

### Oversampling
def oversampling(unbalanced_dataframe, seed):
    from imblearn.over_sampling import SMOTE
    smote = SMOTE(random_state=seed)
    temp = unbalanced_dataframe.drop(['RID'], axis=1)
    X_train, y_train = smote.fit_resample(temp, temp['onset_tight'])

    # X_train에는 RID, onset_3 없음.
    return X_train.drop(['onset_tight'], axis=1), y_train

### Undersampling
# test에 나머지 control sample 추가해서 idx 만 반환
def _under_sampling_idx(unbalanced_data, seed):
    # train에서 ckd, control index 확인
    ckd_idx = unbalanced_data[unbalanced_data['onset_tight'] == 1].index        # 실제 ckd
    control_idx = unbalanced_data[unbalanced_data['onset_tight'] == 0].index    # 실제 control
    # print(control_idx, ckd_idx)

    # ckd 갯수와 동일하게 control idx sampling
    """
    Control CKD 비율 조정
    """
    rng = np.random.default_rng(seed=seed) 
    sampled_control_idx = pd.Index(rng.choice(control_idx, size=len(ckd_idx), replace=False)) # ckd 갯수와 동일하게 sampling
    not_sampled_control_idx = control_idx.difference(sampled_control_idx)

    # 잘 sampling 되었는지 확인
    assert set(sampled_control_idx).issubset(set(control_idx))
    # print(len(sampled_control_idx))

    balanced_idx = sampled_control_idx.append(ckd_idx)

    # return 실제 ckd, 실제 ckd 갯수와 동일한 갯수의 subject, control_idx - ckd_idx
    return ckd_idx, sampled_control_idx, not_sampled_control_idx, balanced_idx

def undersampling(unbalanced_data, seed):
    a, b, c, d = _under_sampling_idx(unbalanced_data, seed)
    under_sampled_data = unbalanced_data.loc[d]
    X_undersampled = under_sampled_data.drop(['RID', 'onset_tight'], axis=1)
    y_undersampled = under_sampled_data['onset_tight']
    return X_undersampled, y_undersampled

def print_cv_results_ML(results_all_seed):
    # 모델별로 시드들의 평균과 표준편차를 구하는 부분
    results_summary = {}

    # 각 시드에 저장된 모델별 결과에 접근
    for seed in results_all_seed:
        for model_name in results_all_seed[seed]:
            if model_name not in results_summary:
                results_summary[model_name] = {
                    'recall': [],
                    'precision': [],
                    'accuracy': [],
                    'auc': [],
                    'recall_std': [],
                    'precision_std': [],
                    'accuracy_std': [],
                    'auc_std': []
                }
            # 각 시드의 성능 값을 추가
            results_summary[model_name]['recall'].append(results_all_seed[seed][model_name]['recall'][0])
            results_summary[model_name]['precision'].append(results_all_seed[seed][model_name]['precision'][0])
            results_summary[model_name]['accuracy'].append(results_all_seed[seed][model_name]['accuracy'][0])
            results_summary[model_name]['auc'].append(results_all_seed[seed][model_name]['auc'][0])
            results_summary[model_name]['recall_std'].append(results_all_seed[seed][model_name]['recall_std'][0])
            results_summary[model_name]['precision_std'].append(results_all_seed[seed][model_name]['precision_std'][0])
            results_summary[model_name]['accuracy_std'].append(results_all_seed[seed][model_name]['accuracy_std'][0])
            results_summary[model_name]['auc_std'].append(results_all_seed[seed][model_name]['auc_std'][0])

    # 모델별로 평균과 표준편차 계산
    for model_name in results_summary:
        print(f"Model: {model_name}")
        
        recall_mean = np.mean(results_summary[model_name]['recall'])
        recall_std = np.mean(results_summary[model_name]['recall_std'])
        
        precision_mean = np.mean(results_summary[model_name]['precision'])
        precision_std = np.mean(results_summary[model_name]['precision_std'])
        
        accuracy_mean = np.mean(results_summary[model_name]['accuracy'])
        accuracy_std = np.mean(results_summary[model_name]['accuracy_std'])
        
        auc_mean = np.mean(results_summary[model_name]['auc'])
        auc_std = np.mean(results_summary[model_name]['auc_std'])
        
        print(f"Recall Precision Accuracy AUC")
        print(f"{recall_mean:.4f}, {precision_mean:.4f}, {accuracy_mean:.4f}, {auc_mean:.4f}")
        print(f"{recall_std:.4f}, {precision_std:.4f}, {accuracy_std:.4f}, {auc_std:.4f}")    
        print("=" * 50)
        
def print_seed_results(results_all_seed):
    # 모델별로 시드들의 평균과 표준편차를 구하는 부분
    results_summary = {}

    # 각 시드에 저장된 모델별 결과에 접근
    for seed in results_all_seed:
        for model_name in results_all_seed[seed]:
            if model_name not in results_summary:
                results_summary[model_name] = {
                    'recall': [],
                    'precision': [],
                    'accuracy': [],
                    'auc': [],
                    'cm' : []
                }
            # 각 시드의 성능 값을 추가
            results_summary[model_name]['recall'].append(results_all_seed[seed][model_name]['recall'][0])
            results_summary[model_name]['precision'].append(results_all_seed[seed][model_name]['precision'][0])
            results_summary[model_name]['accuracy'].append(results_all_seed[seed][model_name]['accuracy'][0])
            results_summary[model_name]['auc'].append(results_all_seed[seed][model_name]['auc'][0])
            results_summary[model_name]['cm'].append(results_all_seed[seed][model_name]['cm'][0])

    # 모델별로 평균과 표준편차 계산
    for model_name in results_summary:
        print(f"Model: {model_name}")
        
        recall_mean = np.mean(results_summary[model_name]['recall'])
        
        precision_mean = np.mean(results_summary[model_name]['precision'])
        
        accuracy_mean = np.mean(results_summary[model_name]['accuracy'])
        
        auc_mean = np.mean(results_summary[model_name]['auc'])
        
        cm_mean = np.round(np.mean(results_summary[model_name]['cm'], axis=0)).astype(int)
        
        print(f"Recall Precision Accuracy AUC")
        print(f"{recall_mean:.4f}, {precision_mean:.4f}, {accuracy_mean:.4f}, {auc_mean:.4f}")
        show_cm(cm_mean, model_name)
        print("=" * 50)

def get_results(y_test, final_prediction, final_probabilities):
    # final_probabilities = (final_probabilities >= 0.55).astype(int)
    cm = confusion_matrix(list(y_test), list(final_prediction))
    print(cm)
    tn, fn, tp, fp  = cm[0][0], cm[1][0], cm[1][1], cm[0][1]
    recall = tp / (fn + tp)
    precision = tp / (fp + tp)
    acc = (tp + tn) / (tn + fn + tp + fp)
    
    # Calculate AUC score
    auc = roc_auc_score(y_test, final_probabilities)
    
    print("Recall \t Precision \t Acc \t AUC")
    print(f"{np.round(recall, 4)} {np.round(precision, 4)} {np.round(acc, 4)} {np.round(auc, 4)}")
    
    # show_cm(cm)
    
    return np.round(recall, 4), np.round(precision, 4), np.round(acc, 4), np.round(auc, 4), cm

def show_cm(cm, model_name=""):
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
    plt.title(f"Confusion Matrix of {model_name}")
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()
    
def model_fitting(model, X_train, y_train):
    model.fit(X_train, y_train)
    return model

def model_eval(fitted_model, X_test, y_test):
    model_prediction = fitted_model.predict(X_test)
    model_probabilities = fitted_model.predict_proba(X_test)[:, 1]
    model_score = fitted_model.score(X_test, y_test)
    print(f"Score with simple {fitted_model} model")
    print(0.5, np.round(model_score, 4))     # accuracy

    get_results(y_test, model_prediction, model_probabilities)

# %% [markdown]
# ### Use Adjusted mean food

# %%
root_path = "/home/user19/pnu_ckd/hexa_preprocessing_after95/0911_dl_models/data/0922_data"
total = pd.read_csv(f"{root_path}/0922_basic_food_adjusted_mean.csv")
basic = pd.read_csv(f"{root_path}/0922_basic_only.csv")
food = pd.read_csv(f"{root_path}/0922_food_adjusted_mean_only.csv")

# %%
total_cols = ['CT1_SEX', 'CT1_AGE', 'CT1_eGFR', 'imp_CT1_SBP', 'imp_CT1_BMI', 'CT1_HB', 'Imp_CT1_ALBUMIN', 'CT1_TCHL', 'imp_new_EDU',
       'imp_new_INCOME', 'imp_new_DRINK', 'imp_new_SMOKE', 'new_CT1_gohyeol', 'CT1_dangnyo', 'CT1_simhyeol',
       'Rice', 'Other grains', 'Noodles and dumplings', 'Wheat flour and bread', 'Potatoes',
    'Sweets', 'Soybean pastes', 'Bean, tofu, and soymilk', 'Nuts', 'Vegetables',
    'Kimchi', 'Mushroom', 'Fruits', 'Red meat and its products', 'White meat and its products',
    'Eggs', 'Fish and shellfish', 'Seaweeds', 'Milk and dairy products', 'Beverage', 'Coffee and tea']

basic_cols = ['CT1_SEX', 'CT1_AGE', 'CT1_eGFR', 'imp_CT1_SBP', 'imp_CT1_BMI', 'CT1_HB', 'Imp_CT1_ALBUMIN', 'CT1_TCHL', 'imp_new_EDU',
       'imp_new_INCOME', 'imp_new_DRINK', 'imp_new_SMOKE', 'new_CT1_gohyeol', 'CT1_dangnyo', 'CT1_simhyeol']

food_cols = ['Rice', 'Other grains', 'Noodles and dumplings', 'Wheat flour and bread', 'Potatoes',
    'Sweets', 'Soybean pastes', 'Bean, tofu, and soymilk', 'Nuts', 'Vegetables',
    'Kimchi', 'Mushroom', 'Fruits', 'Red meat and its products', 'White meat and its products',
    'Eggs', 'Fish and shellfish', 'Seaweeds', 'Milk and dairy products', 'Beverage', 'Coffee and tea']

# %%
total_with_valuable_food_col = ['RID', 'CT1_SEX', 'CT1_AGE', 'CT1_eGFR', 'imp_CT1_SBP', 'imp_CT1_BMI', 'CT1_HB', 'Imp_CT1_ALBUMIN', 'CT1_TCHL', 'imp_new_EDU',
       'imp_new_INCOME', 'imp_new_DRINK', 'imp_new_SMOKE', 'new_CT1_gohyeol', 'CT1_dangnyo', 'CT1_simhyeol', 'onset_tight', 
       'F02_Mean_res', 'F11_Mean_res', 'F01_Mean_res', 'F21_Mean_res', 'F12_Mean_res', 'F04_Mean_res', 'F13_Mean_res']

valuable_food_col = ['RID', 'onset_tight', 'F02_Mean_res', 'F11_Mean_res', 'F01_Mean_res', 'F21_Mean_res', 'F12_Mean_res', 'F04_Mean_res', 'F13_Mean_res']

total_valfood = total[total_with_valuable_food_col]
valfood = food[valuable_food_col]

# %% [markdown]
# ### seed 마다 Control 만 바뀌고, no-cross validation 실험 결과
#
# - 5 seed 평균

# %%
print(total.shape, basic.shape, food.shape)
# Out:
# (57231, 38) (57231, 17) (57231, 23)

# %% [markdown]
# ##### Total

# %%
check = total[['CT1_SEX', 'imp_new_EDU', 'imp_new_INCOME', 'imp_new_DRINK', 'imp_new_SMOKE', 'new_CT1_gohyeol', 'CT1_dangnyo', 'CT1_simhyeol']]
# for col in check.columns:
#     # print(col)
#     print(check[col].value_counts())

# %%
total.columns
# Out:
# Index(['RID', 'CT1_SEX', 'CT1_AGE', 'CT1_eGFR', 'imp_CT1_SBP', 'imp_CT1_BMI',
#        'CT1_HB', 'Imp_CT1_ALBUMIN', 'CT1_TCHL', 'imp_new_EDU',
#        'imp_new_INCOME', 'imp_new_DRINK', 'imp_new_SMOKE', 'new_CT1_gohyeol',
#        'CT1_dangnyo', 'CT1_simhyeol', 'onset_tight', 'F01_Mean_res',
#        'F02_Mean_res', 'F03_Mean_res', 'F04_Mean_res', 'F05_Mean_res',
#        'F06_Mean_res', 'F07_Mean_res', 'F08_Mean_res', 'F09_Mean_res',
#        'F10_Mean_res', 'F11_Mean_res', 'F12_Mean_res', 'F13_Mean_res',
#        'F14_Mean_res', 'F15_Mean_res', 'F16_Mean_res', 'F17_Mean_res',
#        'F18_Mean_res', 'F19_Mean_res', 'F20_Mean_res', 'F21_Mean_res'],
#       dtype='object')

# %%
results_all_seed = {}

# total, basic, food
a, b = divide_testset(total, ratio=0.1)

# test
y_tight3_foodsum_test = b['onset_tight']
X_tight3_foodsum_test = b.drop(['RID', 'onset_tight'], axis=1)

# %%
""" Total Dataset ( Food + Basic ) """

results_all_seed = {}
shap_per_seed = []

for seed in [42, 59, 63, 79, 101]:    
# for seed in [42]:    
    datas = {"original":(), "undersampling":(), "oversampling":()}

    datas['undersampling'] = undersampling(a, seed=seed)        # eGFR 만을 빼면 성능이 줄어든다..
    datas['oversampling'] = oversampling(a, seed=seed)
    y_tight3_foodsum_train = a['onset_tight']
    X_tight3_foodsum_train = a.drop(['RID', 'onset_tight'], axis=1)
    datas['original'] = (X_tight3_foodsum_train, y_tight3_foodsum_train)
    
    results_all_seed[seed] = {}  # 각 시드마다 딕셔너리 생성
    
    for data in ['undersampling']:
        print(f"For {data} dataset!!!")
        # X_test, y_test = datas['test']
        X_train, y_train = datas[data]
        # print(X_train.shape, y_train.shape)
        # print(X_train)
        
        print(f"X_train :: {X_train.shape}, y_train :: {y_train.shape}")
        
        models = (
            SVC(kernel='linear', random_state=seed, probability=True),
            RandomForestClassifier(random_state=seed, max_depth=3),
            LogisticRegression(max_iter=1000, random_state=seed),
            GradientBoostingClassifier(random_state=seed, max_depth=3, learning_rate=0.01),
            GaussianNB(var_smoothing=1e-7),     # 1e-11, 1e-10, 1e-9, 1e-8, 1e-7
        )
        
        for model in models:
            model.fit(X_train, y_train)
            print(f"{model.__class__.__name__} Model fitted!!")
        
        for trained_model in models:
            model_name = trained_model.__class__.__name__  # 모델 이름 저장
            
            # explainer = shap.TreeExplainer(trained_model)
            # shap_val = explainer.shap_values(X_tight3_foodsum_test)
            # shap_per_seed.append(shap_val)
            # print(shap_val.shape)
            
            print("="*30)
            print(f"Predicting {model_name}!!")
            preds = trained_model.predict(X_tight3_foodsum_test)
            model_probabilities = trained_model.predict_proba(X_tight3_foodsum_test)[:, 1]
            print("=" * 30)
            print(seed)
            recall, precision, acc, auc, cm = get_results(y_tight3_foodsum_test, np.array(preds), model_probabilities)
            print("=" * 30)
            
            # 결과 저장
            if model_name not in results_all_seed[seed]:
                results_all_seed[seed][model_name] = {
                    'recall': [], 
                    'precision': [], 
                    'accuracy': [], 
                    'auc': [],
                    'cm' : []
                }
            results_all_seed[seed][model_name]['recall'].append(recall)
            results_all_seed[seed][model_name]['precision'].append(precision)
            results_all_seed[seed][model_name]['accuracy'].append(acc)
            results_all_seed[seed][model_name]['auc'].append(auc)
            results_all_seed[seed][model_name]['cm'].append(cm)
            
print_seed_results(results_all_seed)

shap_per_seed_mean = np.mean(np.array(shap_per_seed), axis=0)
# Out:
# For undersampling dataset!!!
# X_train :: (946, 36), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# ---------------------------------------------------------------------------
# InvalidModelError                         Traceback (most recent call last)
# Cell In[17], line 42
#      39 for trained_model in models:
#      40     model_name = trained_model.__class__.__name__  # 모델 이름 저장
# ---> 42     explainer = shap.TreeExplainer(trained_model)
#      43     shap_val = explainer.shap_values(X_tight3_foodsum_test)
#      44     shap_per_seed.append(shap_val)
#
# File /opt/conda/envs/ckd2/lib/python3.8/site-packages/shap/explainers/_tree.py:175, in TreeExplainer.__init__(self, model, data, model_output, feature_perturbation, feature_names, approximate, **deprecated_options)
#     173 self.feature_perturbation = feature_perturbation
#     174 self.expected_value = None
# --> 175 self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     176 self.model_output = model_output
#     177 #self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#
# File /opt/conda/envs/ckd2/lib/python3.8/site-packages/shap/explainers/_tree.py:1226, in TreeEnsemble.__init__(self, model, data, data_missing, model_output)
#    1224     self.base_offset = model.init_params[param_idx]
#    1225 else:
# -> 1226     raise InvalidModelError("Model type not yet supported by TreeExplainer: " + str(type(model)))
#    1228 # build a dense numpy version of all the tree objects
#    1229 if self.trees is not None and self.trees:
#
# InvalidModelError: Model type not yet supported by TreeExplainer: <class 'sklearn.svm._classes.SVC'>

# %%
plt.figure()
# shap.summary_plot(shap_per_seed_mean, X_tight3_foodsum_test.values, feature_names=X_train.columns.tolist(),       # X_test 자리에 (ndarray)를 넣어야 색깔이 나옴.
#                   cmap='bwr', show=False)
shap.summary_plot(shap_per_seed_mean, X_tight3_foodsum_test.values, feature_names=total_cols,       # X_test 자리에 (ndarray)를 넣어야 색깔이 나옴.
                  cmap='bwr', show=False)
                # shap.summary_plot(shap_per_seed_mean, X_tight3_foodsum_test, feature_names=X_train.columns.tolist(), show=False)
plt.title("Shap summary plot")
plt.show()

# %% [markdown]
# ##### Total + food 중요한거 몇개만 해서 실험.
#
# - 'F02_Mean_res', 'F11_Mean_res', 'F01_Mean_res', 'F21_Mean_res', 'F12_Mean_res', 'F04_Mean_res', 'F13_Mean_res'

# %%
results_all_seed = {}

# total, basic, food, total_valfood
a, b = divide_testset(total_valfood, ratio=0.1)

# test
y_tight3_foodsum_test = b['onset_tight']
X_tight3_foodsum_test = b.drop(['RID', 'onset_tight'], axis=1)

# %%
""" Total Dataset ( Basic + Val_food ) """

results_all_seed = {}

for seed in [42, 59, 63, 79, 101]:    
# for seed in [42]:    
    datas = {"original":(), "undersampling":(), "oversampling":()}

    datas['undersampling'] = undersampling(a, seed=seed)        # eGFR 만을 빼면 성능이 줄어든다..
    datas['oversampling'] = oversampling(a, seed=seed)
    y_tight3_foodsum_train = a['onset_tight']
    X_tight3_foodsum_train = a.drop(['RID', 'onset_tight'], axis=1)
    datas['original'] = (X_tight3_foodsum_train, y_tight3_foodsum_train)
    
    results_all_seed[seed] = {}  # 각 시드마다 딕셔너리 생성
    
    for data in ['undersampling']:
        print(f"For {data} dataset!!!")
        # X_test, y_test = datas['test']
        X_train, y_train = datas[data]
        print(X_train.shape, y_train.shape)
        # print(y_train)
        
        # wei_train_scaler = StandardScaler()
        # X_train = wei_train_scaler.fit_transform(X_train)
        # X_test = wei_train_scaler.transform(X_test)
        print(f"{data} dataset loaded and scaled")
        print(f"X_train :: {X_train.shape}, y_train :: {y_train.shape}")
        
        models = (
            SVC(kernel='linear', random_state=seed, probability=True),
            RandomForestClassifier(random_state=seed, max_depth=3),
            LogisticRegression(max_iter=1000, random_state=seed),
            GradientBoostingClassifier(random_state=seed, max_depth=3, learning_rate=0.01),
            GaussianNB(var_smoothing=1e-7),     # 1e-11, 1e-10, 1e-9, 1e-8, 1e-7
        )
        
        for model in models:
            model.fit(X_train, y_train)
            print(f"{model.__class__.__name__} Model fitted!!")
        
        for trained_model in models:
            model_name = trained_model.__class__.__name__  # 모델 이름 저장
            print("="*30)
            print(f"Predicting {model_name}!!")
            preds = trained_model.predict(X_tight3_foodsum_test)
            model_probabilities = trained_model.predict_proba(X_tight3_foodsum_test)[:, 1]
            print("=" * 30)
            print(seed)
            recall, precision, acc, auc, cm = get_results(y_tight3_foodsum_test, np.array(preds), model_probabilities)
            print("=" * 30)
            
            # 결과 저장
            if model_name not in results_all_seed[seed]:
                results_all_seed[seed][model_name] = {
                    'recall': [], 
                    'precision': [], 
                    'accuracy': [], 
                    'auc': [],
                    'cm' : []
                }
            results_all_seed[seed][model_name]['recall'].append(recall)
            results_all_seed[seed][model_name]['precision'].append(precision)
            results_all_seed[seed][model_name]['accuracy'].append(acc)
            results_all_seed[seed][model_name]['auc'].append(auc)
            results_all_seed[seed][model_name]['cm'].append(cm)
            
print_seed_results(results_all_seed)

# %% [markdown]
# ##### Total save and shap

# %%
# total, basic, food
a, b = divide_testset(total, ratio=0.1)

# test
y_tight3_foodsum_test = b['onset_tight']
X_tight3_foodsum_test = b.drop(['RID', 'onset_tight'], axis=1)

# %%
""" Model Fit & Shap value check & Save (model weight, shap_png, explainer, shap_value)"""

# seed = 59

for seed in [42, 59, 63, 79, 101]:
# for seed in [42]:
    # 저장 경로 설정
    dataset_name = "total_under"
    shap_fig_dir = f"shap_figs_1208_morecontrol/{dataset_name}_seed{seed}"
    os.makedirs(shap_fig_dir, exist_ok=True)  # 폴더가 없으면 생성

    # Data 준비
    datas = {"original":(), "undersampling":(), "oversampling":()}

    datas['undersampling'] = undersampling(a, seed=seed)
    datas['oversampling'] = oversampling(a, seed=seed)
    y_tight3_foodsum_train = a['onset_tight']
    X_tight3_foodsum_train = a.drop(['RID', 'onset_tight'], axis=1)
    datas['original'] = (X_tight3_foodsum_train, y_tight3_foodsum_train)

    for data in ['undersampling']:
        print(f"For {data} dataset!!!")
        X_train, y_train = datas[data]
        print(X_train.shape, y_train.shape)
        # print(y_train)
        
        # wei_train_scaler = StandardScaler()
        # X_train = wei_train_scaler.fit_transform(X_train)
        # X_test = wei_train_scaler.transform(X_test)
        print(f"{data} dataset loaded and scaled")
        print(f"X_train :: {X_train.shape}, y_train :: {y_train.shape}")
        
        shap_values_all_models = {"SVC" : [],
                            "RandomForest" : [],
                            "LogisticRegression" : [],
                            "GradientBoosting" : [],
                            "GNB" : []
                            }
        
        models = [
        ("SVC", SVC(kernel='linear', random_state=seed, probability=True)),     # 50분 소요
        ("RandomForest", RandomForestClassifier(random_state=seed, max_depth=3)),
        ("LogisticRegression", LogisticRegression(max_iter=1000, random_state=seed)),
        ("GradientBoosting", GradientBoostingClassifier(random_state=seed, max_depth=3, learning_rate=0.01)),
        ("GNB", GaussianNB(var_smoothing=1e-7)),     # 1e-11, 1e-10, 1e-9, 1e-8, 1e-7       # 17분 소요
        ]
        
        for name, model in models:
            model.fit(X_train, y_train)
            print(f"{model.__class__.__name__} Model fitted!!")

        for name, trained_model in models:
            # SHAP Explainer 설정
            if name in ["RandomForest", "GradientBoosting"]:
                explainer = shap.TreeExplainer(trained_model)
            elif name in ["SVC", "GNB"]:
                explainer = shap.KernelExplainer(trained_model.predict_proba, shap.sample(X_train, 100))  # 샘플링하여 속도 향상
            elif name == "LogisticRegression":
                explainer = shap.LinearExplainer(trained_model, X_train)
            
            # model save
            save_path_model = os.path.join(shap_fig_dir, f"{trained_model.__class__.__name__}")
            os.makedirs(save_path_model, exist_ok=True)
            save_path_model_weights = os.path.join(save_path_model, f"{trained_model.__class__.__name__}_weights.joblib")
            dump(trained_model, save_path_model_weights)
            print(f"Model weight is saved to {save_path_model_weights}!!")
            
            # explainer save
            save_path_explainer = os.path.join(save_path_model, f"{trained_model.__class__.__name__}_explainer.joblib")
            dump(explainer, save_path_explainer)
            print(f"Explainer for {name} is saved to {save_path_explainer}!!")
            
            # SHAP 값 계산
            if name in ["SVC", "GNB"]:
                shap_values = explainer.shap_values(X_tight3_foodsum_test, silent=True)
            else:
                shap_values = explainer.shap_values(X_tight3_foodsum_test)
            shap_values_all_models[name].append(shap_values)
            
            # Summary plot 그리기 및 저장
            plt.figure()
            save_path_png = os.path.join(save_path_model, f"summary_plot, model_{trained_model.__class__.__name__}.png")

            if name in ["SVC", "RandomForest", "GNB"]:
                shap.summary_plot(shap_values[1], X_tight3_foodsum_test, feature_names=total_cols, show=False)
            else:
                shap.summary_plot(shap_values, X_tight3_foodsum_test, feature_names=total_cols, show=False)
            plt.title(f"Summary plot for of {trained_model.__class__.__name__}")
            plt.savefig(save_path_png)
            plt.close()
            
            # shap value 저장.
            shap_values_save_path = os.path.join(save_path_model, f"shap_values_{name}.pk")
            # pickle을 사용하여 shap_values_all_models 저장
            if name in ["SVC", "RandomForest", "GNB"]:
                with open(shap_values_save_path, 'wb') as f:
                    pickle.dump(shap_values[1], f)
            else:
                with open(shap_values_save_path, 'wb') as f:
                    pickle.dump(shap_values, f)
            print(f"SHAP values of {name} model on seed {seed}, is saved to {shap_values_save_path}.")
# Out:
# For undersampling dataset!!!
# (946, 36) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 36), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed42/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/total_under_seed42/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 42, is saved to shap_figs_1208_morecontrol/total_under_seed42/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed42/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/total_under_seed42/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 42, is saved to shap_figs_1208_morecontrol/total_under_seed42/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed42/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/total_under_seed42/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 42, is saved to shap_figs_1208_morecontrol/total_under_seed42/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed42/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/total_under_seed42/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 42, is saved to shap_figs_1208_morecontrol/total_under_seed42/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed42/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/total_under_seed42/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 42, is saved to shap_figs_1208_morecontrol/total_under_seed42/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 36) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 36), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed59/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/total_under_seed59/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 59, is saved to shap_figs_1208_morecontrol/total_under_seed59/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed59/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/total_under_seed59/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 59, is saved to shap_figs_1208_morecontrol/total_under_seed59/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed59/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/total_under_seed59/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 59, is saved to shap_figs_1208_morecontrol/total_under_seed59/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed59/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/total_under_seed59/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 59, is saved to shap_figs_1208_morecontrol/total_under_seed59/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed59/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/total_under_seed59/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 59, is saved to shap_figs_1208_morecontrol/total_under_seed59/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 36) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 36), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed63/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/total_under_seed63/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 63, is saved to shap_figs_1208_morecontrol/total_under_seed63/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed63/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/total_under_seed63/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 63, is saved to shap_figs_1208_morecontrol/total_under_seed63/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed63/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/total_under_seed63/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 63, is saved to shap_figs_1208_morecontrol/total_under_seed63/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed63/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/total_under_seed63/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 63, is saved to shap_figs_1208_morecontrol/total_under_seed63/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed63/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/total_under_seed63/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 63, is saved to shap_figs_1208_morecontrol/total_under_seed63/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 36) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 36), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed79/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/total_under_seed79/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 79, is saved to shap_figs_1208_morecontrol/total_under_seed79/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed79/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/total_under_seed79/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 79, is saved to shap_figs_1208_morecontrol/total_under_seed79/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed79/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/total_under_seed79/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 79, is saved to shap_figs_1208_morecontrol/total_under_seed79/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed79/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/total_under_seed79/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 79, is saved to shap_figs_1208_morecontrol/total_under_seed79/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed79/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/total_under_seed79/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 79, is saved to shap_figs_1208_morecontrol/total_under_seed79/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 36) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 36), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed101/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/total_under_seed101/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 101, is saved to shap_figs_1208_morecontrol/total_under_seed101/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed101/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/total_under_seed101/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 101, is saved to shap_figs_1208_morecontrol/total_under_seed101/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed101/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/total_under_seed101/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 101, is saved to shap_figs_1208_morecontrol/total_under_seed101/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed101/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/total_under_seed101/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 101, is saved to shap_figs_1208_morecontrol/total_under_seed101/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/total_under_seed101/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/total_under_seed101/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 101, is saved to shap_figs_1208_morecontrol/total_under_seed101/GaussianNB/shap_values_GNB.pk.

# %% [markdown]
# ##### Basic only

# %%
results_all_seed = {}

# total, basic, food
a, b = divide_testset(basic, ratio=0.1)

# test
y_tight3_foodsum_test = b['onset_tight']
X_tight3_foodsum_test = b.drop(['RID', 'onset_tight'], axis=1)

# %%
""" Total Dataset ( Food + Basic ) """

results_all_seed = {}
shap_per_seed = []

for seed in [42, 59, 63, 79, 101]:    
# for seed in [42]:    
    datas = {"original":(), "undersampling":(), "oversampling":()}

    datas['undersampling'] = undersampling(a, seed=seed)        # eGFR 만을 빼면 성능이 줄어든다..
    datas['oversampling'] = oversampling(a, seed=seed)
    y_tight3_foodsum_train = a['onset_tight']
    X_tight3_foodsum_train = a.drop(['RID', 'onset_tight'], axis=1)
    datas['original'] = (X_tight3_foodsum_train, y_tight3_foodsum_train)
    
    results_all_seed[seed] = {}  # 각 시드마다 딕셔너리 생성
    
    for data in ['undersampling']:
        print(f"For {data} dataset!!!")
        # X_test, y_test = datas['test']
        X_train, y_train = datas[data]
        print(X_train.shape, y_train.shape)
        # print(y_train)
        
        # wei_train_scaler = StandardScaler()
        # X_train = wei_train_scaler.fit_transform(X_train)
        # X_test = wei_train_scaler.transform(X_test)
        print(f"{data} dataset loaded and scaled")
        print(f"X_train :: {X_train.shape}, y_train :: {y_train.shape}")
        
        models = (
            SVC(kernel='linear', random_state=seed, probability=True),
            RandomForestClassifier(random_state=seed, max_depth=3),
            LogisticRegression(max_iter=1000, random_state=seed),
            GradientBoostingClassifier(random_state=seed, max_depth=3, learning_rate=0.01),
            GaussianNB(var_smoothing=1e-7),     # 1e-11, 1e-10, 1e-9, 1e-8, 1e-7
        )
        
        # model = models[0]
        for model in models:
            model.fit(X_train, y_train)
            print(f"{model.__class__.__name__} Model fitted!!")
        
        for trained_model in models:
            model_name = trained_model.__class__.__name__  # 모델 이름 저장
            
            # shap
            explainer = shap.TreeExplainer(trained_model)
            shap_val = explainer.shap_values(X_tight3_foodsum_test)
            shap_per_seed.append(shap_val)
            print(shap_val.shape)
            
            print("="*30)
            print(f"Predicting {model_name}!!")
            preds = trained_model.predict(X_tight3_foodsum_test)
            model_probabilities = trained_model.predict_proba(X_tight3_foodsum_test)[:, 1]
            print("=" * 30)
            print(seed)
            recall, precision, acc, auc, cm = get_results(y_tight3_foodsum_test, np.array(preds), model_probabilities)
            print("=" * 30)
            
            # 결과 저장
            if model_name not in results_all_seed[seed]:
                results_all_seed[seed][model_name] = {
                    'recall': [], 
                    'precision': [], 
                    'accuracy': [], 
                    'auc': [],
                    'cm' : []
                }
            results_all_seed[seed][model_name]['recall'].append(recall)
            results_all_seed[seed][model_name]['precision'].append(precision)
            results_all_seed[seed][model_name]['accuracy'].append(acc)
            results_all_seed[seed][model_name]['auc'].append(auc)
            results_all_seed[seed][model_name]['cm'].append(cm)
            
print_seed_results(results_all_seed)
shap_per_seed_mean = np.mean(np.array(shap_per_seed), axis=0)
# Out:
# For undersampling dataset!!!
# (946, 36) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 36), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# ---------------------------------------------------------------------------
# InvalidModelError                         Traceback (most recent call last)
# Cell In[20], line 48
#      45 model_name = trained_model.__class__.__name__  # 모델 이름 저장
#      47 # shap
# ---> 48 explainer = shap.TreeExplainer(trained_model)
#      49 shap_val = explainer.shap_values(X_tight3_foodsum_test)
#      50 shap_per_seed.append(shap_val)
#
# File /opt/conda/envs/ckd2/lib/python3.8/site-packages/shap/explainers/_tree.py:175, in TreeExplainer.__init__(self, model, data, model_output, feature_perturbation, feature_names, approximate, **deprecated_options)
#     173 self.feature_perturbation = feature_perturbation
#     174 self.expected_value = None
# --> 175 self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     176 self.model_output = model_output
#     177 #self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#
# File /opt/conda/envs/ckd2/lib/python3.8/site-packages/shap/explainers/_tree.py:1226, in TreeEnsemble.__init__(self, model, data, data_missing, model_output)
#    1224     self.base_offset = model.init_params[param_idx]
#    1225 else:
# -> 1226     raise InvalidModelError("Model type not yet supported by TreeExplainer: " + str(type(model)))
#    1228 # build a dense numpy version of all the tree objects
#    1229 if self.trees is not None and self.trees:
#
# InvalidModelError: Model type not yet supported by TreeExplainer: <class 'sklearn.svm._classes.SVC'>

# %%
plt.figure()
shap.summary_plot(shap_per_seed_mean, X_tight3_foodsum_test.values, feature_names=X_train.columns.tolist(),       # X_test 자리에 (ndarray)를 넣어야 색깔이 나옴.
                  cmap='bwr', show=False)
                # shap.summary_plot(shap_per_seed_mean, X_tight3_foodsum_test, feature_names=X_train.columns.tolist(), show=False)
plt.title("Shap summary plot")
plt.show()

# %% [markdown]
# ##### Basic only save and shap

# %%
# total, basic, food
a, b = divide_testset(basic, ratio=0.1)

# test
y_tight3_foodsum_test = b['onset_tight']
X_tight3_foodsum_test = b.drop(['RID', 'onset_tight'], axis=1)

# %%
""" Model Fit & Shap value check & Save (model weight, shap_png, explainer, shap_value)"""

# seed = 59

for seed in [42, 59, 63, 79, 101]:
# for seed in [42]:
    # 저장 경로 설정
    dataset_name = "basic_under"
    shap_fig_dir = f"shap_figs_1208_morecontrol/{dataset_name}_seed{seed}"
    os.makedirs(shap_fig_dir, exist_ok=True)  # 폴더가 없으면 생성

    # Data 준비
    datas = {"original":(), "undersampling":(), "oversampling":()}

    datas['undersampling'] = undersampling(a, seed=seed)
    datas['oversampling'] = oversampling(a, seed=seed)
    y_tight3_foodsum_train = a['onset_tight']
    X_tight3_foodsum_train = a.drop(['RID', 'onset_tight'], axis=1)
    datas['original'] = (X_tight3_foodsum_train, y_tight3_foodsum_train)

    for data in ['undersampling']:
        print(f"For {data} dataset!!!")
        X_train, y_train = datas[data]
        print(X_train.shape, y_train.shape)
        # print(y_train)
        
        # wei_train_scaler = StandardScaler()
        # X_train = wei_train_scaler.fit_transform(X_train)
        # X_test = wei_train_scaler.transform(X_test)
        print(f"{data} dataset loaded and scaled")
        print(f"X_train :: {X_train.shape}, y_train :: {y_train.shape}")
        
        shap_values_all_models = {"SVC" : [],
                            "RandomForest" : [],
                            "LogisticRegression" : [],
                            "GradientBoosting" : [],
                            "GNB" : []
                            }
        
        models = [
        ("SVC", SVC(kernel='linear', random_state=seed, probability=True)),     # 50분 소요
        ("RandomForest", RandomForestClassifier(random_state=seed, max_depth=3)),
        ("LogisticRegression", LogisticRegression(max_iter=1000, random_state=seed)),
        ("GradientBoosting", GradientBoostingClassifier(random_state=seed, max_depth=3, learning_rate=0.01)),
        ("GNB", GaussianNB(var_smoothing=1e-7)),     # 1e-11, 1e-10, 1e-9, 1e-8, 1e-7       # 17분 소요
        ]
        
        for name, model in models:
            model.fit(X_train, y_train)
            print(f"{model.__class__.__name__} Model fitted!!")

        for name, trained_model in models:
            # SHAP Explainer 설정
            if name in ["RandomForest", "GradientBoosting"]:
                explainer = shap.TreeExplainer(trained_model)
            elif name in ["SVC", "GNB"]:
                explainer = shap.KernelExplainer(trained_model.predict_proba, shap.sample(X_train, 100))  # 샘플링하여 속도 향상
            elif name == "LogisticRegression":
                explainer = shap.LinearExplainer(trained_model, X_train)
            
            # model save
            save_path_model = os.path.join(shap_fig_dir, f"{trained_model.__class__.__name__}")
            os.makedirs(save_path_model, exist_ok=True)
            save_path_model_weights = os.path.join(save_path_model, f"{trained_model.__class__.__name__}_weights.joblib")
            dump(trained_model, save_path_model_weights)
            print(f"Model weight is saved to {save_path_model_weights}!!")
            
            # explainer save
            save_path_explainer = os.path.join(save_path_model, f"{trained_model.__class__.__name__}_explainer.joblib")
            dump(explainer, save_path_explainer)
            print(f"Explainer for {name} is saved to {save_path_explainer}!!")
            
            # SHAP 값 계산
            if name in ["SVC", "GNB"]:
                shap_values = explainer.shap_values(X_tight3_foodsum_test, silent=True)
            else:
                shap_values = explainer.shap_values(X_tight3_foodsum_test)
            shap_values_all_models[name].append(shap_values)
            
            # Summary plot 그리기 및 저장
            plt.figure()
            save_path_png = os.path.join(save_path_model, f"summary_plot, model_{trained_model.__class__.__name__}.png")

            if name in ["SVC", "RandomForest", "GNB"]:
                shap.summary_plot(shap_values[1], X_tight3_foodsum_test, feature_names=total_cols, show=False)
            else:
                shap.summary_plot(shap_values, X_tight3_foodsum_test, feature_names=total_cols, show=False)
            plt.title(f"Summary plot for of {trained_model.__class__.__name__}")
            plt.savefig(save_path_png)
            plt.close()
            
            # shap value 저장.
            shap_values_save_path = os.path.join(save_path_model, f"shap_values_{name}.pk")
            # pickle을 사용하여 shap_values_all_models 저장
            if name in ["SVC", "RandomForest", "GNB"]:
                with open(shap_values_save_path, 'wb') as f:
                    pickle.dump(shap_values[1], f)
            else:
                with open(shap_values_save_path, 'wb') as f:
                    pickle.dump(shap_values, f)
            print(f"SHAP values of {name} model on seed {seed}, is saved to {shap_values_save_path}.")
# Out:
# For undersampling dataset!!!
# (946, 15) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 15), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed42/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/basic_under_seed42/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 42, is saved to shap_figs_1208_morecontrol/basic_under_seed42/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed42/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/basic_under_seed42/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 42, is saved to shap_figs_1208_morecontrol/basic_under_seed42/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed42/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/basic_under_seed42/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 42, is saved to shap_figs_1208_morecontrol/basic_under_seed42/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed42/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/basic_under_seed42/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 42, is saved to shap_figs_1208_morecontrol/basic_under_seed42/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed42/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/basic_under_seed42/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 42, is saved to shap_figs_1208_morecontrol/basic_under_seed42/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 15) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 15), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed59/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/basic_under_seed59/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 59, is saved to shap_figs_1208_morecontrol/basic_under_seed59/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed59/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/basic_under_seed59/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 59, is saved to shap_figs_1208_morecontrol/basic_under_seed59/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed59/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/basic_under_seed59/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 59, is saved to shap_figs_1208_morecontrol/basic_under_seed59/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed59/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/basic_under_seed59/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 59, is saved to shap_figs_1208_morecontrol/basic_under_seed59/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed59/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/basic_under_seed59/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 59, is saved to shap_figs_1208_morecontrol/basic_under_seed59/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 15) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 15), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed63/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/basic_under_seed63/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 63, is saved to shap_figs_1208_morecontrol/basic_under_seed63/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed63/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/basic_under_seed63/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 63, is saved to shap_figs_1208_morecontrol/basic_under_seed63/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed63/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/basic_under_seed63/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 63, is saved to shap_figs_1208_morecontrol/basic_under_seed63/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed63/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/basic_under_seed63/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 63, is saved to shap_figs_1208_morecontrol/basic_under_seed63/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed63/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/basic_under_seed63/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 63, is saved to shap_figs_1208_morecontrol/basic_under_seed63/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 15) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 15), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed79/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/basic_under_seed79/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 79, is saved to shap_figs_1208_morecontrol/basic_under_seed79/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed79/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/basic_under_seed79/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 79, is saved to shap_figs_1208_morecontrol/basic_under_seed79/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed79/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/basic_under_seed79/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 79, is saved to shap_figs_1208_morecontrol/basic_under_seed79/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed79/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/basic_under_seed79/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 79, is saved to shap_figs_1208_morecontrol/basic_under_seed79/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed79/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/basic_under_seed79/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 79, is saved to shap_figs_1208_morecontrol/basic_under_seed79/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 15) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 15), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed101/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/basic_under_seed101/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 101, is saved to shap_figs_1208_morecontrol/basic_under_seed101/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed101/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/basic_under_seed101/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 101, is saved to shap_figs_1208_morecontrol/basic_under_seed101/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed101/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/basic_under_seed101/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 101, is saved to shap_figs_1208_morecontrol/basic_under_seed101/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed101/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/basic_under_seed101/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 101, is saved to shap_figs_1208_morecontrol/basic_under_seed101/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/basic_under_seed101/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/basic_under_seed101/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 101, is saved to shap_figs_1208_morecontrol/basic_under_seed101/GaussianNB/shap_values_GNB.pk.

# %% [markdown]
# ##### Food only

# %%
results_all_seed = {}

# total, basic, food
a, b = divide_testset(food, ratio=0.1)

# test
y_tight3_foodsum_test = b['onset_tight']
X_tight3_foodsum_test = b.drop(['RID', 'onset_tight'], axis=1)

# %%
""" Total Dataset ( Food + Basic ) """

results_all_seed = {}

for seed in [42, 59, 63, 79, 101]:    
# for seed in [42]:    
    datas = {"original":(), "undersampling":(), "oversampling":()}

    datas['undersampling'] = undersampling(a, seed=seed)        # eGFR 만을 빼면 성능이 줄어든다..
    datas['oversampling'] = oversampling(a, seed=seed)
    y_tight3_foodsum_train = a['onset_tight']
    X_tight3_foodsum_train = a.drop(['RID', 'onset_tight'], axis=1)
    datas['original'] = (X_tight3_foodsum_train, y_tight3_foodsum_train)
    
    results_all_seed[seed] = {}  # 각 시드마다 딕셔너리 생성
    
    for data in ['undersampling']:
        print(f"For {data} dataset!!!")
        # X_test, y_test = datas['test']
        X_train, y_train = datas[data]
        print(X_train.shape, y_train.shape)
        # print(y_train)
        
        # wei_train_scaler = StandardScaler()
        # X_train = wei_train_scaler.fit_transform(X_train)
        # X_test = wei_train_scaler.transform(X_test)
        print(f"{data} dataset loaded and scaled")
        print(f"X_train :: {X_train.shape}, y_train :: {y_train.shape}")
        
        models = (
            SVC(kernel='linear', random_state=seed, probability=True),
            RandomForestClassifier(random_state=seed, max_depth=3),
            LogisticRegression(max_iter=1000, random_state=seed),
            GradientBoostingClassifier(random_state=seed, max_depth=3, learning_rate=0.01),
            GaussianNB(var_smoothing=1e-7),     # 1e-11, 1e-10, 1e-9, 1e-8, 1e-7
        )
        
        model = models[0]
        for model in models:
            model.fit(X_train, y_train)
            print(f"{model.__class__.__name__} Model fitted!!")
        
        for trained_model in models:
            model_name = trained_model.__class__.__name__  # 모델 이름 저장
            print("="*30)
            print(f"Predicting {model_name}!!")
            preds = trained_model.predict(X_tight3_foodsum_test)
            model_probabilities = trained_model.predict_proba(X_tight3_foodsum_test)[:, 1]
            print("=" * 30)
            print(seed)
            recall, precision, acc, auc, cm = get_results(y_tight3_foodsum_test, np.array(preds), model_probabilities)
            print("=" * 30)
            
            # 결과 저장
            if model_name not in results_all_seed[seed]:
                results_all_seed[seed][model_name] = {
                    'recall': [], 
                    'precision': [], 
                    'accuracy': [], 
                    'auc': [],
                    'cm' : []
                }
            results_all_seed[seed][model_name]['recall'].append(recall)
            results_all_seed[seed][model_name]['precision'].append(precision)
            results_all_seed[seed][model_name]['accuracy'].append(acc)
            results_all_seed[seed][model_name]['auc'].append(auc)
            results_all_seed[seed][model_name]['cm'].append(cm)
            
print_seed_results(results_all_seed)

# %% [markdown]
# ##### Val food only
#
# - 'F02_Mean_res', 'F11_Mean_res', 'F01_Mean_res', 'F21_Mean_res', 'F12_Mean_res', 'F04_Mean_res', 'F13_Mean_res'

# %%
results_all_seed = {}

# total, basic, food
a, b = divide_testset(valfood, ratio=0.1)

# test
y_tight3_foodsum_test = b['onset_tight']
X_tight3_foodsum_test = b.drop(['RID', 'onset_tight'], axis=1)

# %%
""" Total Dataset ( Food + Basic ) """

results_all_seed = {}

for seed in [42, 59, 63, 79, 101]:    
# for seed in [42]:    
    datas = {"original":(), "undersampling":(), "oversampling":()}

    datas['undersampling'] = undersampling(a, seed=seed)        # eGFR 만을 빼면 성능이 줄어든다..
    datas['oversampling'] = oversampling(a, seed=seed)
    y_tight3_foodsum_train = a['onset_tight']
    X_tight3_foodsum_train = a.drop(['RID', 'onset_tight'], axis=1)
    datas['original'] = (X_tight3_foodsum_train, y_tight3_foodsum_train)
    
    results_all_seed[seed] = {}  # 각 시드마다 딕셔너리 생성
    
    for data in ['undersampling']:
        print(f"For {data} dataset!!!")
        # X_test, y_test = datas['test']
        X_train, y_train = datas[data]
        print(X_train.shape, y_train.shape)
        # print(y_train)
        
        # wei_train_scaler = StandardScaler()
        # X_train = wei_train_scaler.fit_transform(X_train)
        # X_test = wei_train_scaler.transform(X_test)
        print(f"{data} dataset loaded and scaled")
        print(f"X_train :: {X_train.shape}, y_train :: {y_train.shape}")
        
        models = (
            SVC(kernel='linear', random_state=seed, probability=True),
            RandomForestClassifier(random_state=seed, max_depth=3),
            LogisticRegression(max_iter=1000, random_state=seed),
            GradientBoostingClassifier(random_state=seed, max_depth=3, learning_rate=0.01),
            GaussianNB(var_smoothing=1e-7),     # 1e-11, 1e-10, 1e-9, 1e-8, 1e-7
        )
        
        model = models[0]
        for model in models:
            model.fit(X_train, y_train)
            print(f"{model.__class__.__name__} Model fitted!!")
        
        for trained_model in models:
            model_name = trained_model.__class__.__name__  # 모델 이름 저장
            print("="*30)
            print(f"Predicting {model_name}!!")
            preds = trained_model.predict(X_tight3_foodsum_test)
            model_probabilities = trained_model.predict_proba(X_tight3_foodsum_test)[:, 1]
            print("=" * 30)
            print(seed)
            recall, precision, acc, auc, cm = get_results(y_tight3_foodsum_test, np.array(preds), model_probabilities)
            print("=" * 30)
            
            # 결과 저장
            if model_name not in results_all_seed[seed]:
                results_all_seed[seed][model_name] = {
                    'recall': [], 
                    'precision': [], 
                    'accuracy': [], 
                    'auc': [],
                    'cm' : []
                }
            results_all_seed[seed][model_name]['recall'].append(recall)
            results_all_seed[seed][model_name]['precision'].append(precision)
            results_all_seed[seed][model_name]['accuracy'].append(acc)
            results_all_seed[seed][model_name]['auc'].append(auc)
            results_all_seed[seed][model_name]['cm'].append(cm)
            
print_seed_results(results_all_seed)

# %% [markdown]
# ##### Food only save and shap

# %%
# total, basic, food
a, b = divide_testset(food, ratio=0.1)

# test
y_tight3_foodsum_test = b['onset_tight']
X_tight3_foodsum_test = b.drop(['RID', 'onset_tight'], axis=1)

# %%
""" Model Fit & Shap value check & Save (model weight, shap_png, explainer, shap_value)"""

# seed = 59

for seed in [42, 59, 63, 79, 101]:
# for seed in [42]:
    # 저장 경로 설정
    dataset_name = "food_under"
    shap_fig_dir = f"shap_figs_1208_morecontrol/{dataset_name}_seed{seed}"
    os.makedirs(shap_fig_dir, exist_ok=True)  # 폴더가 없으면 생성

    # Data 준비
    datas = {"original":(), "undersampling":(), "oversampling":()}

    datas['undersampling'] = undersampling(a, seed=seed)
    datas['oversampling'] = oversampling(a, seed=seed)
    y_tight3_foodsum_train = a['onset_tight']
    X_tight3_foodsum_train = a.drop(['RID', 'onset_tight'], axis=1)
    datas['original'] = (X_tight3_foodsum_train, y_tight3_foodsum_train)

    for data in ['undersampling']:
        print(f"For {data} dataset!!!")
        X_train, y_train = datas[data]
        print(X_train.shape, y_train.shape)
        # print(y_train)
        
        # wei_train_scaler = StandardScaler()
        # X_train = wei_train_scaler.fit_transform(X_train)
        # X_test = wei_train_scaler.transform(X_test)
        print(f"{data} dataset loaded and scaled")
        print(f"X_train :: {X_train.shape}, y_train :: {y_train.shape}")
        
        shap_values_all_models = {"SVC" : [],
                            "RandomForest" : [],
                            "LogisticRegression" : [],
                            "GradientBoosting" : [],
                            "GNB" : []
                            }
        
        models = [
        ("SVC", SVC(kernel='linear', random_state=seed, probability=True)),     # 50분 소요
        ("RandomForest", RandomForestClassifier(random_state=seed, max_depth=3)),
        ("LogisticRegression", LogisticRegression(max_iter=1000, random_state=seed)),
        ("GradientBoosting", GradientBoostingClassifier(random_state=seed, max_depth=3, learning_rate=0.01)),
        ("GNB", GaussianNB(var_smoothing=1e-7)),     # 1e-11, 1e-10, 1e-9, 1e-8, 1e-7       # 17분 소요
        ]
        
        for name, model in models:
            model.fit(X_train, y_train)
            print(f"{model.__class__.__name__} Model fitted!!")

        for name, trained_model in models:
            # SHAP Explainer 설정
            if name in ["RandomForest", "GradientBoosting"]:
                explainer = shap.TreeExplainer(trained_model)
            elif name in ["SVC", "GNB"]:
                explainer = shap.KernelExplainer(trained_model.predict_proba, shap.sample(X_train, 100))  # 샘플링하여 속도 향상
            elif name == "LogisticRegression":
                explainer = shap.LinearExplainer(trained_model, X_train)
            
            # model save
            save_path_model = os.path.join(shap_fig_dir, f"{trained_model.__class__.__name__}")
            os.makedirs(save_path_model, exist_ok=True)
            save_path_model_weights = os.path.join(save_path_model, f"{trained_model.__class__.__name__}_weights.joblib")
            dump(trained_model, save_path_model_weights)
            print(f"Model weight is saved to {save_path_model_weights}!!")
            
            # explainer save
            save_path_explainer = os.path.join(save_path_model, f"{trained_model.__class__.__name__}_explainer.joblib")
            dump(explainer, save_path_explainer)
            print(f"Explainer for {name} is saved to {save_path_explainer}!!")
            
            # SHAP 값 계산
            if name in ["SVC", "GNB"]:
                shap_values = explainer.shap_values(X_tight3_foodsum_test, silent=True)
            else:
                shap_values = explainer.shap_values(X_tight3_foodsum_test)
            shap_values_all_models[name].append(shap_values)
            
            # Summary plot 그리기 및 저장
            plt.figure()
            save_path_png = os.path.join(save_path_model, f"summary_plot, model_{trained_model.__class__.__name__}.png")

            if name in ["SVC", "RandomForest", "GNB"]:
                shap.summary_plot(shap_values[1], X_tight3_foodsum_test, feature_names=total_cols, show=False)
            else:
                shap.summary_plot(shap_values, X_tight3_foodsum_test, feature_names=total_cols, show=False)
            plt.title(f"Summary plot for of {trained_model.__class__.__name__}")
            plt.savefig(save_path_png)
            plt.close()
            
            # shap value 저장.
            shap_values_save_path = os.path.join(save_path_model, f"shap_values_{name}.pk")
            # pickle을 사용하여 shap_values_all_models 저장
            if name in ["SVC", "RandomForest", "GNB"]:
                with open(shap_values_save_path, 'wb') as f:
                    pickle.dump(shap_values[1], f)
            else:
                with open(shap_values_save_path, 'wb') as f:
                    pickle.dump(shap_values, f)
            print(f"SHAP values of {name} model on seed {seed}, is saved to {shap_values_save_path}.")
# Out:
# For undersampling dataset!!!
# (946, 21) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 21), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed42/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/food_under_seed42/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 42, is saved to shap_figs_1208_morecontrol/food_under_seed42/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed42/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/food_under_seed42/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 42, is saved to shap_figs_1208_morecontrol/food_under_seed42/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed42/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/food_under_seed42/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 42, is saved to shap_figs_1208_morecontrol/food_under_seed42/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed42/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/food_under_seed42/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 42, is saved to shap_figs_1208_morecontrol/food_under_seed42/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed42/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/food_under_seed42/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 42, is saved to shap_figs_1208_morecontrol/food_under_seed42/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 21) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 21), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed59/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/food_under_seed59/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 59, is saved to shap_figs_1208_morecontrol/food_under_seed59/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed59/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/food_under_seed59/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 59, is saved to shap_figs_1208_morecontrol/food_under_seed59/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed59/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/food_under_seed59/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 59, is saved to shap_figs_1208_morecontrol/food_under_seed59/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed59/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/food_under_seed59/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 59, is saved to shap_figs_1208_morecontrol/food_under_seed59/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed59/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/food_under_seed59/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 59, is saved to shap_figs_1208_morecontrol/food_under_seed59/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 21) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 21), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed63/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/food_under_seed63/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 63, is saved to shap_figs_1208_morecontrol/food_under_seed63/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed63/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/food_under_seed63/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 63, is saved to shap_figs_1208_morecontrol/food_under_seed63/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed63/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/food_under_seed63/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 63, is saved to shap_figs_1208_morecontrol/food_under_seed63/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed63/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/food_under_seed63/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 63, is saved to shap_figs_1208_morecontrol/food_under_seed63/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed63/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/food_under_seed63/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 63, is saved to shap_figs_1208_morecontrol/food_under_seed63/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 21) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 21), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed79/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/food_under_seed79/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 79, is saved to shap_figs_1208_morecontrol/food_under_seed79/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed79/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/food_under_seed79/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 79, is saved to shap_figs_1208_morecontrol/food_under_seed79/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed79/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/food_under_seed79/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 79, is saved to shap_figs_1208_morecontrol/food_under_seed79/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed79/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/food_under_seed79/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 79, is saved to shap_figs_1208_morecontrol/food_under_seed79/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed79/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/food_under_seed79/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 79, is saved to shap_figs_1208_morecontrol/food_under_seed79/GaussianNB/shap_values_GNB.pk.
# For undersampling dataset!!!
# (946, 21) (946,)
# undersampling dataset loaded and scaled
# X_train :: (946, 21), y_train :: (946,)
# SVC Model fitted!!
# RandomForestClassifier Model fitted!!
# LogisticRegression Model fitted!!
# GradientBoostingClassifier Model fitted!!
# GaussianNB Model fitted!!
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed101/SVC/SVC_weights.joblib!!
# Explainer for SVC is saved to shap_figs_1208_morecontrol/food_under_seed101/SVC/SVC_explainer.joblib!!
# SHAP values of SVC model on seed 101, is saved to shap_figs_1208_morecontrol/food_under_seed101/SVC/shap_values_SVC.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed101/RandomForestClassifier/RandomForestClassifier_weights.joblib!!
# Explainer for RandomForest is saved to shap_figs_1208_morecontrol/food_under_seed101/RandomForestClassifier/RandomForestClassifier_explainer.joblib!!
# SHAP values of RandomForest model on seed 101, is saved to shap_figs_1208_morecontrol/food_under_seed101/RandomForestClassifier/shap_values_RandomForest.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed101/LogisticRegression/LogisticRegression_weights.joblib!!
# Explainer for LogisticRegression is saved to shap_figs_1208_morecontrol/food_under_seed101/LogisticRegression/LogisticRegression_explainer.joblib!!
# SHAP values of LogisticRegression model on seed 101, is saved to shap_figs_1208_morecontrol/food_under_seed101/LogisticRegression/shap_values_LogisticRegression.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed101/GradientBoostingClassifier/GradientBoostingClassifier_weights.joblib!!
# Explainer for GradientBoosting is saved to shap_figs_1208_morecontrol/food_under_seed101/GradientBoostingClassifier/GradientBoostingClassifier_explainer.joblib!!
# SHAP values of GradientBoosting model on seed 101, is saved to shap_figs_1208_morecontrol/food_under_seed101/GradientBoostingClassifier/shap_values_GradientBoosting.pk.
# Model weight is saved to shap_figs_1208_morecontrol/food_under_seed101/GaussianNB/GaussianNB_weights.joblib!!
# Explainer for GNB is saved to shap_figs_1208_morecontrol/food_under_seed101/GaussianNB/GaussianNB_explainer.joblib!!
# SHAP values of GNB model on seed 101, is saved to shap_figs_1208_morecontrol/food_under_seed101/GaussianNB/shap_values_GNB.pk.
